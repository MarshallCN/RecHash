# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/RecHash
# Out:
# /content/drive/.shortcut-targets-by-id/1RbfabtwaBLjUw91iLjZ9z3eugQIdP4hb/RecHash

# %%
import numpy as np
import json
from evaluate import evaluate
from utility import *
import pandas as pd

# %% [markdown]
# # Evaluate

# %%
dataset = 'amazon'
# setting = '2core'
setting = '2core' if dataset == 'movielens' else '2core_clothing'
pred_dir = "predictions/%s/" %(dataset)
input_dir = "dataset/%s/%s/" % (dataset, setting)
result_dir = 'results/%s/' % dataset

dat = 'ml' if dataset == 'movielens' else 'az'

# %%
input_dir
# Out:
# 'dataset/amazon/2core_clothing/'

# %%
rw_metapaths = [ "userknn_ml_2core_nb10",
                'RH_user_based_az_bmRH_UP_6bit_1r_BU_nb10',
                'RH_user_based_az_bmRH_Uh(U)_BU_nb10',
                'RH_user_based_bmUh(U)_BU_az_UPBP_nw100_nb10_emb300_2core_clothing',
                'RH_user_based_bmUh(U)_BU_az_UserItemMatrix_nw100_nb10_emb300_2core_clohting',
                'RH_user_based_az_bmRH_UPh(P)_BU_nb10',
                'RH_user_based_az_bmRH_UPUh(U)_BU_nb10',

                'bpr_none_1_az_emb300_2core_clothing',
                 'kgat_cnn_az_emb300_2core_clothing',
                'vbpr_none_1_az_emb300_2core_clothing',
                'kgat_cnn_az_emb300_2core_clothing',
                
]
block_metapaths = ['CF','UP','Uh(U)', 'Uh(U)', 'Uh(U)', 'UPh(P)','UPUh(U)',
                   
                   'bpr','kgat_cnn','vbpr','kgat_cnn']


pred_files =  ["userknn_az_2core_clothing_nb10.json",
               "RH_user_based_az_bmRH_UP_6bit_1r_BU_nb10.json", 
               'RH_user_based_az_bmRH_Uh(U)_BU_nb10.json',
               'RH_user_based_bmUh(U)_BU_az_UPBP_nw100_nb10_emb300_2core_clothing.json',
               'RH_user_based_bmUh(U)_BU_az_UserItemMatrix_nw100_nb10_emb300_2core_clohting.json',
               'RH_user_based_az_bmRH_UPh(P)_BU_nb10.json',
               'RH_user_based_az_bmRH_UPUh(U)_BU_nb10.json',

              'bpr_none_1_az_emb300_2core_clothing.json',
               'kgat_cnn_az_emb300_2core_clothing.json',
               'vbpr_none_1_az_emb300_2core_clothing.json',
               'kgat_cnn_az_emb300_2core_clothing.json'
               ]

# %%
# labels = ['CF','RH UPh(P)','RH Uh(U)','SRH Uh(U)','SRH UPh(P)','RH UP','RH UPUP','RH UPU','RH UPUh(U)']
labels = [ "CF",
                'RH_UP_6bit_1r_BU',
                'RH_Uh(U)_BU_nb10',
                'RH_Uh(U)_BU_az_UPBP',
                'RH_Uh(U)_BU',
                'RH_UPh(P)_BU_nb10',
                'RH_UPUh(U)_BU_nb10',
          

                'bpr',
                 'kgat',
                'vbpr',
                'kgat']

# %%
# labels = ["CF"] + \
#              ['RH %s'%bm for bm in block_metapaths] +\
#              ['SRH %s'%bm for bm in rw_metapaths]

# %%
len(pred_files),len(labels)
# Out:
# (11, 11)

# %%
pd.DataFrame({
    'labels':labels,
    'pred':pred_files})
# Out:
#                  labels                                               pred
# 0      userknn_ml_2core                userknn_az_2core_clothing_nb10.json
# 1      RH_UP_6bit_1r_BU      RH_user_based_az_bmRH_UP_6bit_1r_BU_nb10.json
# 2      RH_Uh(U)_BU_nb10           RH_user_based_az_bmRH_Uh(U)_BU_nb10.json
# 3   RH_Uh(U)_BU_az_UPBP  RH_user_based_bmUh(U)_BU_az_UPBP_nw100_nb10_em...
# 4           RH_Uh(U)_BU  RH_user_based_bmUh(U)_BU_az_UserItemMatrix_nw1...
# 5     RH_UPh(P)_BU_nb10          RH_user_based_az_bmRH_UPh(P)_BU_nb10.json
# 6    RH_UPUh(U)_BU_nb10         RH_user_based_az_bmRH_UPUh(U)_BU_nb10.json
# 7                   bpr           bpr_none_1_az_emb300_2core_clothing.json
# 8                  kgat             kgat_cnn_az_emb300_2core_clothing.json
# 9                  vbpr          vbpr_none_1_az_emb300_2core_clothing.json
# 10                 kgat             kgat_cnn_az_emb300_2core_clothing.json

# %%
with open(input_dir + "train.json", 'r') as fp:
    train_set = json.load(fp)
with open(input_dir + "test.json", 'r') as fp:
    test_set = json.load(fp)
with open(input_dir + "item.json", 'r') as fp:
    item_data = json.load(fp)
all_users = list(train_set.keys())
all_items = list(item_data.keys())

# %%
import os
df = None
try:
    os.mkdir(result_dir + "%s/"%th)
except:
    pass
    
assert len(pred_files) == len(labels)
    
for label, pred_file in zip(labels, pred_files): 
        
      result_file = result_dir + pred_file.replace('.json', '.csv') 
        
      if os.path.exists(result_file):
          print("file exists: ",end='')
      else:
        print("make new file: ",end='')
        prediction = json.load(open(pred_dir + pred_file, 'r'))   
        print(len(prediction))
            
        fres = open(result_file, 'w')
        write_header(fres, dataset)    
        evaluate(prediction, dataset, input_dir, all_users, all_items, fres, 'user-item', rank_weights_prec=True, rank_weights_rec=False)
        fres.close()

        print(result_file)
      result = pd.read_csv(result_file, sep='\t')
      result['label'] = label
        
      if df is None:
        df = result
      else:
        df = pd.concat([df, result])
            
df = df.reindex(columns=(['label'] + list([a for a in df.columns if a != 'label']) ))

# df.to_csv(result_dir + '%s_baselines_eval_hash.csv'%(dat), index=False)
df.to_csv(result_dir + '%s_eval_hash_new.csv'%(dat), index=False)
# Out:
# file exists: file exists: file exists: file exists: file exists: file exists: file exists: file exists: file exists: file exists: file exists:

# %%
df
# Out:
#                  label      vtype    group  avg_prec_1  avg_prec_5  \
# 0     userknn_ml_2core  user-item    2to10    0.000234    0.000112
# 1     userknn_ml_2core  user-item   10to20    0.000646    0.000215
# 2     userknn_ml_2core  user-item   20to50    0.003711    0.000891
# 3     userknn_ml_2core  user-item  50to100    0.000000    0.000000
# 4     userknn_ml_2core  user-item      all    0.000330    0.000134
# 0     RH_UP_6bit_1r_BU  user-item    2to10    0.002041    0.001068
# 1     RH_UP_6bit_1r_BU  user-item   10to20    0.000000    0.002165
# 2     RH_UP_6bit_1r_BU  user-item   20to50    0.125000    0.045833
# 3     RH_UP_6bit_1r_BU  user-item  50to100    0.000000    0.000000
# 4     RH_UP_6bit_1r_BU  user-item      all    0.003472    0.001834
# 0     RH_Uh(U)_BU_nb10  user-item    2to10    0.002041    0.001000
# 1     RH_Uh(U)_BU_nb10  user-item   10to20    0.000000    0.000649
# 2     RH_Uh(U)_BU_nb10  user-item   20to50    0.000000    0.005000
# 3     RH_Uh(U)_BU_nb10  user-item  50to100    0.000000    0.000000
# 4     RH_Uh(U)_BU_nb10  user-item      all    0.001736    0.001007
# 0  RH_Uh(U)_BU_az_UPBP  user-item    2to10    0.002147    0.000783
# 1  RH_Uh(U)_BU_az_UPBP  user-item   10to20    0.004386    0.001075
# 2  RH_Uh(U)_BU_az_UPBP  user-item   20to50    0.000000    0.000000
# 3  RH_Uh(U)_BU_az_UPBP  user-item  50to100         NaN         NaN
# 4  RH_Uh(U)_BU_az_UPBP  user-item      all    0.002388    0.000807
# 0          RH_Uh(U)_BU  user-item    2to10    0.005296    0.001224
# 1          RH_Uh(U)_BU  user-item   10to20    0.009390    0.003161
# 2          RH_Uh(U)_BU  user-item   20to50    0.000000    0.002500
# 3          RH_Uh(U)_BU  user-item  50to100         NaN         NaN
# 4          RH_Uh(U)_BU  user-item      all    0.005789    0.001556
# 0    RH_UPh(P)_BU_nb10  user-item    2to10    0.004082    0.000952
# 1    RH_UPh(P)_BU_nb10  user-item   10to20    0.000000    0.003030
# 2    RH_UPh(P)_BU_nb10  user-item   20to50    0.000000    0.005000
# 3    RH_UPh(P)_BU_nb10  user-item  50to100    0.000000    0.000000
# 4    RH_UPh(P)_BU_nb10  user-item      all    0.003472    0.001285
# 0   RH_UPUh(U)_BU_nb10  user-item    2to10    0.002041    0.000694
# 1   RH_UPUh(U)_BU_nb10  user-item   10to20    0.000000    0.002035
# 2   RH_UPUh(U)_BU_nb10  user-item   20to50    0.000000    0.017500
# 3   RH_UPUh(U)_BU_nb10  user-item  50to100    0.000000    0.000000
# 4   RH_UPUh(U)_BU_nb10  user-item      all    0.001736    0.001105
# 0                  bpr  user-item    2to10    0.002750    0.001836
# 1                  bpr  user-item   10to20    0.007540    0.005154
# 2                  bpr  user-item   20to50    0.014842    0.008986
# 3                  bpr  user-item  50to100    0.000000    0.013333
# 4                  bpr  user-item      all    0.003479    0.002330
# 0                 kgat  user-item    2to10    0.007490    0.002649
# 1                 kgat  user-item   10to20    0.017449    0.007091
# 2                 kgat  user-item   20to50    0.033395    0.011973
# 3                 kgat  user-item  50to100    0.000000    0.019608
# 4                 kgat  user-item      all    0.009015    0.003308
# 0                 vbpr  user-item    2to10    0.004037    0.001462
# 1                 vbpr  user-item   10to20    0.009263    0.003313
# 2                 vbpr  user-item   20to50    0.022263    0.006370
# 3                 vbpr  user-item  50to100    0.000000    0.016078
# 4                 vbpr  user-item      all    0.004901    0.001753
# 0                 kgat  user-item    2to10    0.007490    0.002649
# 1                 kgat  user-item   10to20    0.017449    0.007091
# 2                 kgat  user-item   20to50    0.033395    0.011973
# 3                 kgat  user-item  50to100    0.000000    0.019608
# 4                 kgat  user-item      all    0.009015    0.003308
#
#    avg_prec_10  avg_prec_50  avg_prec_100  avg_rec_1  avg_rec_5  ...  \
# 0     0.000067     0.000017      0.000009   0.000190   0.000464  ...
# 1     0.000118     0.000031      0.000016   0.000215   0.000344  ...
# 2     0.000476     0.000103      0.000051   0.000478   0.000602  ...
# 3     0.000000     0.000160      0.000080   0.000000   0.000000  ...
# 4     0.000079     0.000020      0.000010   0.000197   0.000451  ...
# 0     0.000705     0.000167      0.000083   0.001020   0.003554  ...
# 1     0.001212     0.000335      0.000168   0.000000   0.003247  ...
# 2     0.022917     0.004762      0.002381   0.020833   0.032407  ...
# 3     0.000000     0.000000      0.000000   0.000000   0.000000  ...
# 4     0.001080     0.000253      0.000126   0.001157   0.003908  ...
# 0     0.000534     0.000132      0.000066   0.002041   0.003724  ...
# 1     0.000599     0.000211      0.000105   0.000000   0.001082  ...
# 2     0.004583     0.000917      0.000458   0.000000   0.003571  ...
# 3     0.000000     0.000000      0.000000   0.000000   0.000000  ...
# 4     0.000598     0.000154      0.000077   0.001736   0.003363  ...
# 0     0.000439     0.000106      0.000053   0.001687   0.003188  ...
# 1     0.000660     0.000180      0.000091   0.001279   0.001535  ...
# 2     0.000000     0.000020      0.000020   0.000000   0.000000  ...
# 3          NaN          NaN           NaN        NaN        NaN  ...
# 4     0.000460     0.000114      0.000057   0.001614   0.002943  ...
# 0     0.000765     0.000171      0.000085   0.004413   0.005001  ...
# 1     0.001639     0.000361      0.000180   0.003130   0.004700  ...
# 2     0.001713     0.000385      0.000202   0.000000   0.001620  ...
# 3          NaN          NaN           NaN        NaN        NaN  ...
# 4     0.000924     0.000205      0.000103   0.004100   0.004867  ...
# 0     0.000591     0.000146      0.000073   0.003061   0.003741  ...
# 1     0.001822     0.000530      0.000265   0.000000   0.004690  ...
# 2     0.010139     0.002245      0.001123   0.000000   0.002778  ...
# 3     0.000000     0.000000      0.000000   0.000000   0.000000  ...
# 4     0.000887     0.000226      0.000113   0.002604   0.003848  ...
# 0     0.000393     0.000104      0.000052   0.001020   0.002449  ...
# 1     0.001792     0.000417      0.000209   0.000000   0.003030  ...
# 2     0.012917     0.002889      0.001444   0.000000   0.013194  ...
# 3     0.000000     0.000000      0.000000   0.000000   0.000000  ...
# 4     0.000753     0.000185      0.000092   0.000868   0.002672  ...
# 0     0.001124     0.000283      0.000149   0.002121   0.007107  ...
# 1     0.003316     0.000876      0.000464   0.002226   0.007695  ...
# 2     0.005857     0.001740      0.000951   0.002159   0.006235  ...
# 3     0.010285     0.005040      0.003159   0.000000   0.003791  ...
# 4     0.001451     0.000375      0.000198   0.002133   0.007162  ...
# 0     0.001515     0.000361      0.000187   0.005822   0.010257  ...
# 1     0.004070     0.000996      0.000521   0.005317   0.010714  ...
# 2     0.007306     0.001862      0.000997   0.004627   0.008340  ...
# 3     0.012213     0.004485      0.002809   0.000000   0.005392  ...
# 4     0.001900     0.000458      0.000239   0.005743   0.010282  ...
# 0     0.000833     0.000202      0.000105   0.003291   0.005852  ...
# 1     0.001908     0.000460      0.000243   0.002844   0.005073  ...
# 2     0.003639     0.000957      0.000512   0.002911   0.004120  ...
# 3     0.010595     0.003075      0.001642   0.000000   0.003904  ...
# 4     0.001002     0.000244      0.000128   0.003232   0.005736  ...
# 0     0.001515     0.000361      0.000187   0.005822   0.010257  ...
# 1     0.004070     0.000996      0.000521   0.005317   0.010714  ...
# 2     0.007306     0.001862      0.000997   0.004627   0.008340  ...
# 3     0.012213     0.004485      0.002809   0.000000   0.005392  ...
# 4     0.001900     0.000458      0.000239   0.005743   0.010282  ...
#
#    norm_ep_5  norm_ep_10  norm_ep_50  norm_ep_100  norm_er_1  norm_er_5  \
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
# 0        NaN         NaN         NaN          NaN        NaN        NaN
# 1        NaN         NaN         NaN          NaN        NaN        NaN
# 2        NaN         NaN         NaN          NaN        NaN        NaN
# 3        NaN         NaN         NaN          NaN        NaN        NaN
# 4        NaN         NaN         NaN          NaN        NaN        NaN
#
#    norm_er_10  norm_er_50  norm_er_100  Unnamed: 72
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
# 0         NaN         NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN
#
# [55 rows x 74 columns]

# %% [markdown]
# # Plot the results

# %%
# filename of all results combined and ready to be plotted 

# df_result_filename = result_dir +  'ml_selected_RH.csv'
df_result_filename = result_dir +  'az_eval_hash_new.csv'

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.cm import get_cmap
import numpy as np
import itertools
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 13})

N = [1,5,10,50,100]
precol = ['avg_prec_%d'%n for n in N]
reccol = ['norm_rec_%d'%n for n in N]
f1col = ['norm_f1_%d'%n for n in N]
epcol = ['norm_ep_%d'%n for n in N]
ercol = ['norm_er_%d'%n for n in N]
genre_cov= ['genre_cov_%d'%n for n in N]
nov = ['novelty_%d'%n for n in N]
linewidth = 3
markersize =9

if dataset == 'movielens' :
    #ranges = ['2to10', '10to20', '20to50', '50to100', '100to1276', 'all']
    ranges = [ 'all']
else:
    ranges = [ 'all']

def plot(result, group, path):
    
    global N, precol, reccol, f1col, epcol, ercol
    # figsize = (30,25)
    figsize = (13,5)
    
    marker, linestyle, color = get_style()    
    fig = plt.figure(figsize=figsize)
    ax = plt.subplot(1,2,1)
    x = N
    plt.xscale('symlog')
    for row in result.itertuples():
        y = result.loc[result['label']==row.label][precol].values[0]
        label = row.label
        label = label.replace("_BU", '')        
        
        if " RW_UPT_" in label:
            label = label.replace("RW_UPT_", "$\mathcal{M}_1$")
        elif " RW_UPU_" in label:
            label = label.replace("RW_UPU_", "$\mathcal{M}_{2}$")       
            
        elif " RH_UPT_" in label:
            label = label.replace("RH_UPT_", "$\mathcal{M}_1$")
        elif " RH_UPU_" in label:
            label = label.replace("RH_UPU_", "$\mathcal{M}_{2}$")
               
        elif " UPTh(T)" in label:
            label = label.replace("UPTh(T)", "$\mathcal{M}_{3}$")
        elif " UPUh(U)" in label:
            label = label.replace("UPUh(U)", "$\mathcal{M}_{4}$")
        
        label = label.replace(' ', '_')
        ax.plot(x, y,label=label, marker = next(marker), linestyle=next(linestyle), color=next(color), linewidth=linewidth, markersize=markersize)
    plt.xlabel('N')
    plt.ylabel('MAP@N')
    plt.title('MAP@N')
    #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.legend()
    
    #fig = plt.figure(figsize=(3,2))
    marker, linestyle, color = get_style()
    ax = plt.subplot(1,2,2)
    x = N
    plt.xscale('symlog')
    for row in result.itertuples():
        y = result.loc[result['label']==row.label][reccol].values[0]
        label = row.label
        label = label.replace("_BU", '')        
        
        if " RW_UPT_" in label:
            label = label.replace("RW_UPT_", "$\mathcal{M}_1$")
        elif " RW_UPU_" in label:
            label = label.replace("RW_UPU_", "$\mathcal{M}_{2}$")       
            
        elif " RH_UPT_" in label:
            label = label.replace("RH_UPT_", "$\mathcal{M}_1$")
        elif " RH_UPU_" in label:
            label = label.replace("RH_UPU_", "$\mathcal{M}_{2}$")
               
        elif " UPTh(T)" in label:
            label = label.replace("UPTh(T)", "$\mathcal{M}_{3}$")
        elif " UPUh(U)" in label:
            label = label.replace("UPUh(U)", "$\mathcal{M}_{4}$")
        label = label.replace(' ', '_')
        
        ax.plot(x, y,label=label, marker = next(marker), linestyle=next(linestyle), color=next(color), linewidth=linewidth, markersize=markersize)
    plt.xlabel('N')
    plt.ylabel('Recall@N')
    plt.title('Recall@N')
    #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.legend()
    
    plt.tight_layout(pad=0.5)
    plt.savefig(path.replace('.csv', '_acc_%s.png'%group), bbox_inches='tight', dpi=250)
    plt.show()

# %%
def get_style():
    markerset = itertools.cycle(('+', 'x', '^', '*', 'o', 's', 'd', 'p', '<', '>')) 
    lineset = itertools.cycle(('-', ':', ':', ':', ':', ':', ':', ':', ':', ':', ':', ':', ':', ':', ':', ':',))
    colorset = itertools.cycle(( 'r', 'g', 'b', 'k', 'm', 'c', 'peru', 'purple', 'olive', 'dimgray', 'orange', 'lightgreen', 'pink', 'navy'))
    return markerset, lineset, colorset

# %%
df = pd.read_csv(df_result_filename)

for r in ranges:
    print('%s_baselines_eval.csv'%(dat))
    plot(df[df['group'] == r], r, result_dir + '%s_hash_allRH_baselines.csv'%(dat))
# Out:
# az_baselines_eval.csv

# %%
df = pd.read_csv(df_result_filename)

for r in ranges:
    print('%s_baselines_eval.csv'%(dat))
    plot(df[df['group'] == r], r, result_dir + '%s_hash_allRH_baselines.csv'%(dat))
# Out:
# az_baselines_eval.csv

# %%
df = pd.read_csv(df_result_filename)

df['label'] = df['label'].str.replace('0.6sample_5epo_16bit_1r', '')
df['label'] = df['label'].str.replace('RN', 'RH')
df['label'] = df['label'].str.replace('16bit_1r', '')
df['label'] = df['label'].str.replace('8bit_1r', '')
df['label'] = df['label'].str.replace('6bit_1r', '')
df['label'] = df['label'].str.replace('RH_UPTU', 'RH_UPUT')
df['label'] = df['label'].str.replace('RW_UPTU', 'RW_UPUT')

for r in ranges:
    print('%s_baselines_eval.csv'%(dat))
    plot(df[df['group'] == r], r, result_dir + '%s_hash_allRH_baselines.csv'%(dat))
# Out:
# <ipython-input-16-2adb67f619c1>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['label'] = df['label'].str.replace('0.6sample_5epo_16bit_1r', '')
# az_baselines_eval.csv

# %%
df_result_filename = result_dir +  'ml_baselines_eval_hash.csv'

df = pd.read_csv(df_result_filename)

for r in ranges:
    print('%s_baselines_eval.csv'%(dat))
    plot(df[df['group'] == r], r, result_dir + '%s_hash_allRH_baselines.csv'%(dat))
# Out:
# ml_baselines_eval.csv
